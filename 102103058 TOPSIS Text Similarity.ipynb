# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("/Users/krishuppal/Desktop/modelsdata.xlsx")

# %%
data
# Out:
#                 Model  Precision  Recall  Rejection Rate     F1  Accuracy
# 0         sim jaccard      1.000   0.383           1.000  0.554     0.691
# 1         sim overlap      0.990   0.362           0.995  0.530     0.679
# 2      simoverlap,IDF      0.978   0.233           0.995  0.377     0.614
# 3   simoverlap.phrase      1.000   0.637           1.000  0.778     0.819
# 4        simTF,vector      0.993   0.689           0.995  0.813     0.842
# 5     simTFIDF,vector      1.000   0.762           1.000  0.865     0.881
# 6        simTFIDF,nov      1.000   0.192           1.000  0.322     0.600
# 7         simidentity      0.980   0.767           0.984  0.860     0.876
# 8              simssv      0.670   0.969           0.523  0.790     0.746
# 9              simsem      0.983   0.912           0.984  0.946     0.948
# 10      simsimsem,IDF      0.949   0.575           0.969  0.716     0.772
# 11             sim wo      0.644   0.487           0.731  0.555     0.609
# 12          simssv+wo      0.680   0.979           0.539  0.803     0.759
# 13          simsem+wo      0.963   0.933           0.964  0.948     0.948

# %%
df = pd.DataFrame(data)
df.set_index('Model', inplace=True)
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x=df.index, y='Precision', palette='viridis')
plt.title('Model Comparison - Precision')
plt.xlabel('Model')
plt.ylabel('Precision Score')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = pd.DataFrame(data)
df.set_index('Model', inplace=True)
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x=df.index, y='Recall', palette='viridis')
plt.title('Model Comparison - Recall')
plt.xlabel('Model')
plt.ylabel('Recall')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = pd.DataFrame(data)
df.set_index('Model', inplace=True)
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x=df.index, y='Rejection Rate', palette='viridis')
plt.title('Model Comparison - Rejection Rate')
plt.xlabel('Model')
plt.ylabel('Rejection Rate')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = pd.DataFrame(data)
df.set_index('Model', inplace=True)
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x=df.index, y='F1', palette='viridis')
plt.title('Model Comparison - F1')
plt.xlabel('Model')
plt.ylabel('F1 Score')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df = pd.DataFrame(data)
df.set_index('Model', inplace=True)
plt.figure(figsize=(12, 8))
sns.barplot(data=df, x=df.index, y='Accuracy', palette='viridis')
plt.title('Model Comparison - Accuracy')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
data=np.array(data)
data2=data
data2
# Out:
# array([['sim jaccard', 1.0, 0.383, 1.0, 0.554, 0.691],
#        ['sim overlap', 0.99, 0.362, 0.995, 0.53, 0.679],
#        ['simoverlap,IDF', 0.978, 0.233, 0.995, 0.377, 0.614],
#        ['simoverlap.phrase', 1.0, 0.637, 1.0, 0.778, 0.819],
#        ['simTF,vector', 0.993, 0.689, 0.995, 0.813, 0.842],
#        ['simTFIDF,vector', 1.0, 0.762, 1.0, 0.865, 0.881],
#        ['simTFIDF,nov', 1.0, 0.192, 1.0, 0.322, 0.6],
#        ['simidentity', 0.98, 0.767, 0.984, 0.86, 0.876],
#        ['simssv', 0.67, 0.969, 0.523, 0.79, 0.746],
#        ['simsem', 0.983, 0.912, 0.984, 0.946, 0.948],
#        ['simsimsem,IDF', 0.949, 0.575, 0.969, 0.716, 0.772],
#        ['sim wo', 0.644, 0.487, 0.731, 0.555, 0.609],
#        ['simssv+wo', 0.68, 0.979, 0.539, 0.803, 0.759],
#        ['simsem+wo', 0.963, 0.933, 0.964, 0.948, 0.948]], dtype=object)

# %%
column_index = 1
column_data = data[:, column_index]
column_norm = np.linalg.norm(column_data)
normalized_column = column_data / column_norm
data[:, column_index] = normalized_column
print("Normalized data:", data)
# Out:
# Normalized data: [['sim jaccard' 0.288635113300386 0.383 1.0 0.554 0.691]
#  ['sim overlap' 0.2857487621673821 0.362 0.995 0.53 0.679]
#  ['simoverlap,IDF' 0.28228514080777745 0.233 0.995 0.377 0.614]
#  ['simoverlap.phrase' 0.288635113300386 0.637 1.0 0.778 0.819]
#  ['simTF,vector' 0.28661466750728326 0.689 0.995 0.813 0.842]
#  ['simTFIDF,vector' 0.288635113300386 0.762 1.0 0.865 0.881]
#  ['simTFIDF,nov' 0.288635113300386 0.192 1.0 0.322 0.6]
#  ['simidentity' 0.28286241103437826 0.767 0.984 0.86 0.876]
#  ['simssv' 0.1933855259112586 0.969 0.523 0.79 0.746]
#  ['simsem' 0.2837283163742794 0.912 0.984 0.946 0.948]
#  ['simsimsem,IDF' 0.2739147225220663 0.575 0.969 0.716 0.772]
#  ['sim wo' 0.18588101296544857 0.487 0.731 0.555 0.609]
#  ['simssv+wo' 0.19627187704426247 0.979 0.539 0.803 0.759]
#  ['simsem+wo' 0.2779556141082717 0.933 0.964 0.948 0.948]]

# %%
column_index = 2
column_data = data[:, column_index]
column_norm = np.linalg.norm(column_data)
normalized_column = column_data / column_norm
data[:, column_index] = normalized_column
print("Normalized data:", data)
# Out:
# Normalized data: [['sim jaccard' 0.288635113300386 0.14924388624877372 1.0 0.554 0.691]
#  ['sim overlap' 0.2857487621673821 0.1410608011019741 0.995 0.53 0.679]
#  ['simoverlap,IDF' 0.28228514080777745 0.09079327805734798 0.995 0.377
#   0.614]
#  ['simoverlap.phrase' 0.288635113300386 0.24822024945292132 1.0 0.778
#   0.819]
#  ['simTF,vector' 0.28661466750728326 0.2684831269592822 0.995 0.813 0.842]
#  ['simTFIDF,vector' 0.288635113300386 0.29692908961244274 1.0 0.865 0.881]
#  ['simTFIDF,nov' 0.288635113300386 0.07481677848502495 1.0 0.322 0.6]
#  ['simidentity' 0.28286241103437826 0.2988774432188236 0.984 0.86 0.876]
#  ['simssv' 0.1933855259112586 0.3775909289166102 0.523 0.79 0.746]
#  ['simsem' 0.2837283163742794 0.3553796978038685 0.984 0.946 0.948]
#  ['simsimsem,IDF' 0.2739147225220663 0.22406066473379865 0.969 0.716
#   0.772]
#  ['sim wo' 0.18588101296544857 0.18976964126149556 0.731 0.555 0.609]
#  ['simssv+wo' 0.19627187704426247 0.381487636129372 0.539 0.803 0.759]
#  ['simsem+wo' 0.2779556141082717 0.36356278295066813 0.964 0.948 0.948]]

# %%
column_index = 3
column_data = data[:, column_index]
column_norm = np.linalg.norm(column_data)
normalized_column = column_data / column_norm
data[:, column_index] = normalized_column
print("Normalized data:", data)
# Out:
# Normalized data: [['sim jaccard' 0.288635113300386 0.14924388624877372 0.29021182375929244
#   0.554 0.691]
#  ['sim overlap' 0.2857487621673821 0.1410608011019741 0.288760764640496
#   0.53 0.679]
#  ['simoverlap,IDF' 0.28228514080777745 0.09079327805734798
#   0.288760764640496 0.377 0.614]
#  ['simoverlap.phrase' 0.288635113300386 0.24822024945292132
#   0.29021182375929244 0.778 0.819]
#  ['simTF,vector' 0.28661466750728326 0.2684831269592822 0.288760764640496
#   0.813 0.842]
#  ['simTFIDF,vector' 0.288635113300386 0.29692908961244274
#   0.29021182375929244 0.865 0.881]
#  ['simTFIDF,nov' 0.288635113300386 0.07481677848502495
#   0.29021182375929244 0.322 0.6]
#  ['simidentity' 0.28286241103437826 0.2988774432188236
#   0.28556843457914377 0.86 0.876]
#  ['simssv' 0.1933855259112586 0.3775909289166102 0.15178078382610996 0.79
#   0.746]
#  ['simsem' 0.2837283163742794 0.3553796978038685 0.28556843457914377
#   0.946 0.948]
#  ['simsimsem,IDF' 0.2739147225220663 0.22406066473379865
#   0.28121525722275437 0.716 0.772]
#  ['sim wo' 0.18588101296544857 0.18976964126149556 0.21214484316804277
#   0.555 0.609]
#  ['simssv+wo' 0.19627187704426247 0.381487636129372 0.15642417300625863
#   0.803 0.759]
#  ['simsem+wo' 0.2779556141082717 0.36356278295066813 0.2797641981039579
#   0.948 0.948]]

# %%
column_index = 4
column_data = data[:, column_index]
column_norm = np.linalg.norm(column_data)
normalized_column = column_data / column_norm
data[:, column_index] = normalized_column
print("Normalized data:", data)
# Out:
# Normalized data: [['sim jaccard' 0.288635113300386 0.14924388624877372 0.29021182375929244
#   0.2026855598897466 0.691]
#  ['sim overlap' 0.2857487621673821 0.1410608011019741 0.288760764640496
#   0.1939049580172666 0.679]
#  ['simoverlap,IDF' 0.28228514080777745 0.09079327805734798
#   0.288760764640496 0.1379286210802066 0.614]
#  ['simoverlap.phrase' 0.288635113300386 0.24822024945292132
#   0.29021182375929244 0.2846378440328932 0.819]
#  ['simTF,vector' 0.28661466750728326 0.2684831269592822 0.288760764640496
#   0.29744288843025984 0.842]
#  ['simTFIDF,vector' 0.288635113300386 0.29692908961244274
#   0.29021182375929244 0.3164675258206332 0.881]
#  ['simTFIDF,nov' 0.288635113300386 0.07481677848502495
#   0.29021182375929244 0.11780640845577328 0.6]
#  ['simidentity' 0.28286241103437826 0.2988774432188236
#   0.28556843457914377 0.3146382337638665 0.876]
#  ['simssv' 0.1933855259112586 0.3775909289166102 0.15178078382610996
#   0.2890281449691332 0.746]
#  ['simsem' 0.2837283163742794 0.3553796978038685 0.28556843457914377
#   0.34610205714025316 0.948]
#  ['simsimsem,IDF' 0.2739147225220663 0.22406066473379865
#   0.28121525722275437 0.26195462252898655 0.772]
#  ['sim wo' 0.18588101296544857 0.18976964126149556 0.21214484316804277
#   0.20305141830109993 0.609]
#  ['simssv+wo' 0.19627187704426247 0.381487636129372 0.15642417300625863
#   0.29378430431672653 0.759]
#  ['simsem+wo' 0.2779556141082717 0.36356278295066813 0.2797641981039579
#   0.34683377396295983 0.948]]

# %%
column_index = 5
column_data = data[:, column_index]
column_norm = np.linalg.norm(column_data)
normalized_column = column_data / column_norm
data[:, column_index] = normalized_column
print("Normalized data:", data)
# Out:
# Normalized data: [['sim jaccard' 0.288635113300386 0.14924388624877372 0.29021182375929244
#   0.2026855598897466 0.23707171489838533]
#  ['sim overlap' 0.2857487621673821 0.1410608011019741 0.288760764640496
#   0.1939049580172666 0.23295469524747275]
#  ['simoverlap,IDF' 0.28228514080777745 0.09079327805734798
#   0.288760764640496 0.1379286210802066 0.21065417213836268]
#  ['simoverlap.phrase' 0.288635113300386 0.24822024945292132
#   0.29021182375929244 0.2846378440328932 0.2809865911747867]
#  ['simTF,vector' 0.28661466750728326 0.2684831269592822 0.288760764640496
#   0.29744288843025984 0.28887754550570255]
#  ['simTFIDF,vector' 0.288635113300386 0.29692908961244274
#   0.29021182375929244 0.3164675258206332 0.3022578593711686]
#  ['simTFIDF,nov' 0.288635113300386 0.07481677848502495
#   0.29021182375929244 0.11780640845577328 0.20585098254563128]
#  ['simidentity' 0.28286241103437826 0.2988774432188236
#   0.28556843457914377 0.3146382337638665 0.30054243451662166]
#  ['simssv' 0.1933855259112586 0.3775909289166102 0.15178078382610996
#   0.2890281449691332 0.2559413882984016]
#  ['simsem' 0.2837283163742794 0.3553796978038685 0.28556843457914377
#   0.34610205714025316 0.32524455242209743]
#  ['simsimsem,IDF' 0.2739147225220663 0.22406066473379865
#   0.28121525722275437 0.26195462252898655 0.2648615975420456]
#  ['sim wo' 0.18588101296544857 0.18976964126149556 0.21214484316804277
#   0.20305141830109993 0.20893874728381576]
#  ['simssv+wo' 0.19627187704426247 0.381487636129372 0.15642417300625863
#   0.29378430431672653 0.2604014929202236]
#  ['simsem+wo' 0.2779556141082717 0.36356278295066813 0.2797641981039579
#   0.34683377396295983 0.32524455242209743]]

# %%
data
# Out:
# array([['sim jaccard', 0.288635113300386, 0.14924388624877372,
#         0.29021182375929244, 0.2026855598897466, 0.23707171489838533],
#        ['sim overlap', 0.2857487621673821, 0.1410608011019741,
#         0.288760764640496, 0.1939049580172666, 0.23295469524747275],
#        ['simoverlap,IDF', 0.28228514080777745, 0.09079327805734798,
#         0.288760764640496, 0.1379286210802066, 0.21065417213836268],
#        ['simoverlap.phrase', 0.288635113300386, 0.24822024945292132,
#         0.29021182375929244, 0.2846378440328932, 0.2809865911747867],
#        ['simTF,vector', 0.28661466750728326, 0.2684831269592822,
#         0.288760764640496, 0.29744288843025984, 0.28887754550570255],
#        ['simTFIDF,vector', 0.288635113300386, 0.29692908961244274,
#         0.29021182375929244, 0.3164675258206332, 0.3022578593711686],
#        ['simTFIDF,nov', 0.288635113300386, 0.07481677848502495,
#         0.29021182375929244, 0.11780640845577328, 0.20585098254563128],
#        ['simidentity', 0.28286241103437826, 0.2988774432188236,
#         0.28556843457914377, 0.3146382337638665, 0.30054243451662166],
#        ['simssv', 0.1933855259112586, 0.3775909289166102,
#         0.15178078382610996, 0.2890281449691332, 0.2559413882984016],
#        ['simsem', 0.2837283163742794, 0.3553796978038685,
#         0.28556843457914377, 0.34610205714025316, 0.32524455242209743],
#        ['simsimsem,IDF', 0.2739147225220663, 0.22406066473379865,
#         0.28121525722275437, 0.26195462252898655, 0.2648615975420456],
#        ['sim wo', 0.18588101296544857, 0.18976964126149556,
#         0.21214484316804277, 0.20305141830109993, 0.20893874728381576],
#        ['simssv+wo', 0.19627187704426247, 0.381487636129372,
#         0.15642417300625863, 0.29378430431672653, 0.2604014929202236],
#        ['simsem+wo', 0.2779556141082717, 0.36356278295066813,
#         0.2797641981039579, 0.34683377396295983, 0.32524455242209743]],
#       dtype=object)

# %%
data=data[:,1:]

# %%
data = data.astype(float)

# %%
weights=np.array([1,1,1,1,1])
weights
# Out:
# array([1, 1, 1, 1, 1])

# %%
impact = ['+', '+', '+', '+', '+']
impact
# Out:
# ['+', '+', '+', '+', '+']

# %%
data=data*weights*np.where(np.array(impact) == '+', 1, -1)
data
# Out:
# array([[0.28863511, 0.14924389, 0.29021182, 0.20268556, 0.23707171],
#        [0.28574876, 0.1410608 , 0.28876076, 0.19390496, 0.2329547 ],
#        [0.28228514, 0.09079328, 0.28876076, 0.13792862, 0.21065417],
#        [0.28863511, 0.24822025, 0.29021182, 0.28463784, 0.28098659],
#        [0.28661467, 0.26848313, 0.28876076, 0.29744289, 0.28887755],
#        [0.28863511, 0.29692909, 0.29021182, 0.31646753, 0.30225786],
#        [0.28863511, 0.07481678, 0.29021182, 0.11780641, 0.20585098],
#        [0.28286241, 0.29887744, 0.28556843, 0.31463823, 0.30054243],
#        [0.19338553, 0.37759093, 0.15178078, 0.28902814, 0.25594139],
#        [0.28372832, 0.3553797 , 0.28556843, 0.34610206, 0.32524455],
#        [0.27391472, 0.22406066, 0.28121526, 0.26195462, 0.2648616 ],
#        [0.18588101, 0.18976964, 0.21214484, 0.20305142, 0.20893875],
#        [0.19627188, 0.38148764, 0.15642417, 0.2937843 , 0.26040149],
#        [0.27795561, 0.36356278, 0.2797642 , 0.34683377, 0.32524455]])

# %%
ideal_sol = np.max(data, axis=0)
negative_ideal_sol = np.min(data, axis=0)
ideal_sol
# Out:
# array([0.28863511, 0.38148764, 0.29021182, 0.34683377, 0.32524455])

# %%
negative_ideal_sol
# Out:
# array([0.18588101, 0.07481678, 0.15178078, 0.11780641, 0.20585098])

# %%
distance_to_ideal = np.linalg.norm(data - ideal_sol, axis=1)
distance_to_negative_ideal = np.linalg.norm(data - negative_ideal_sol, axis=1)

# %%
topsis_score = distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

# %%
topsis_score
# Out:
# array([0.42051776, 0.39932218, 0.31080626, 0.6653853 , 0.7164455 ,
#        0.79402778, 0.30069183, 0.79305824, 0.64819668, 0.93901743,
#        0.58438493, 0.34420142, 0.6618334 , 0.94715807])

# %%
def rank_rows(data, column_index, ascending=True):
    column_values = data[:, column_index]
    sorted_indices = np.argsort(column_values, kind='quicksort')  # Use quicksort for stable sorting

    if not ascending:
        sorted_indices = sorted_indices[::-1]

    ranks = np.empty_like(sorted_indices)
    ranks[sorted_indices] = np.arange(len(sorted_indices)) + 1

    return ranks

column_index_to_rank = 4 
ascending_order = True  

row_ranks = rank_rows(data, column_index_to_rank, ascending_order)
print("Row Ranks based on column {}: {}".format(column_index_to_rank, row_ranks))
# Out:
# Row Ranks based on column 4: [ 5  4  3  9 10 12  1 11  6 13  8  2  7 14]

# %%
df = pd.DataFrame(data2)
df['Rank'] = row_ranks

print(df)
# Out:
#                     0         1         2         3         4         5  Rank
# 0         sim jaccard  0.288635  0.149244  0.290212  0.202686  0.237072     5
# 1         sim overlap  0.285749  0.141061  0.288761  0.193905  0.232955     4
# 2      simoverlap,IDF  0.282285  0.090793  0.288761  0.137929  0.210654     3
# 3   simoverlap.phrase  0.288635   0.24822  0.290212  0.284638  0.280987     9
# 4        simTF,vector  0.286615  0.268483  0.288761  0.297443  0.288878    10
# 5     simTFIDF,vector  0.288635  0.296929  0.290212  0.316468  0.302258    12
# 6        simTFIDF,nov  0.288635  0.074817  0.290212  0.117806  0.205851     1
# 7         simidentity  0.282862  0.298877  0.285568  0.314638  0.300542    11
# 8              simssv  0.193386  0.377591  0.151781  0.289028  0.255941     6
# 9              simsem  0.283728   0.35538  0.285568  0.346102  0.325245    13
# 10      simsimsem,IDF  0.273915  0.224061  0.281215  0.261955  0.264862     8
# 11             sim wo  0.185881   0.18977  0.212145  0.203051  0.208939     2
# 12          simssv+wo  0.196272  0.381488  0.156424  0.293784  0.260401     7
# 13          simsem+wo  0.277956  0.363563  0.279764  0.346834  0.325245    14

# %%
excel_file_path = '/Users/krishuppal/Desktop/102103058-model-for-text-similarity.xlsx'
df.to_excel(excel_file_path, index=False)
